# %% [markdown]
# # 研究論文の国際学会採択予測
#
# ## コンペティション概要
# 本コンペでは、論文のタイトル、アブストラクト、キーワードなどの自然言語情報から、その論文が国際学会で採択されるかどうかを予測していただきます。
#
# ## 背景・目的
# 国際学会での論文掲載は、研究者にとっての重要な節目であり、その実績はその後のキャリアに大きな影響を与えます。
#
# 論文が採択される可能性は、文章の質、テーマ、研究の新しさなどが影響します。特に、多くの論文が集まる国際学会においては、始めに査読の目に留まる、アブストラクトの品質が特に重要です。
#
# そこで、本コンペでは、論文本文を含まないタイトル・アブストラクト等の情報が、国際学会の採択率にどの程度影響するかを考察したいと思います。
#
# コンペティションを通して、審査者がどのような判断基準で採択を決定しているのかなどの洞察につながれば幸いです。

# %% [markdown]
# ## Config

# %%
import pandas as pd
import numpy as np
import sklearn
import gensim
import nltk
# !python3 --version
print(pd.__version__)
print(np.__version__)
print(sklearn.__version__)
import matplotlib.pyplot as plt
# print(matplotlib.__version__)
print(gensim.__version__)
# Out:
# Python 3.10.11
# 1.5.3
# 1.22.4
# 1.2.2
# 4.3.1

# %%
from google.colab import drive
import os
import pathlib
import tensorflow as tf

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_dir + 'train_data.csv'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9a50691b797d> in <cell line: 1>()
# ----> 1 input_dir + 'train_data.csv'
#
# NameError: name 'input_dir' is not defined

# %%
input_dir ="drive/My Drive/Colab Notebooks/competition/202304/" #Drive

train_file = input_dir + 'train_data.csv'
test_file = input_dir + 'test_data.csv'
df = pd.read_csv(train_file, index_col='id')
df_t = pd.read_csv(test_file, index_col='id')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4974 entries, 1 to 4974
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     4974 non-null   object
#  1   year      4974 non-null   int64
#  2   abstract  4974 non-null   object
#  3   keywords  4494 non-null   object
#  4   y         4974 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 233.2+ KB

# %% [markdown]
# ## EDA

# %%
df['year'].unique()
# Out:
# array([2018, 2019, 2020])

# %%
df.head()
# Out:
#                                                 title  year  \
# id
# 1        Hierarchical Adversarially Learned Inference  2018
# 2      Learning to Compute Word Embeddings On the Fly  2018
# 3    Graph2Seq: Scalable Learning Dynamics for Graphs  2018
# 4   Generating Differentially Private Datasets Usi...  2018
# 5   Representing dynamically: An active process fo...  2018
#
#                                              abstract  \
# id
# 1   We propose a novel hierarchical generative mod...
# 2   Words in natural language follow a Zipfian dis...
# 3   Neural networks are increasingly used as a gen...
# 4   In this paper, we present a technique for gene...
# 5   We propose an unsupervised method for building...
#
#                                              keywords  y
# id
# 1   generative, hierarchical, unsupervised, semisu...  0
# 2       NLU, word embeddings, representation learning  0
# 3                                                 NaN  0
# 4   generative adversarial networks, differential ...  0
# 5   Generative Models, Latent representations, Pre...  0

# %%
#データセットの分布
t_nums = df['title'][df['y']==1].count()
f_nums = df['title'][df['y']==0].count()

print(f'True labels:{t_nums}')
print(f'False labels:{f_nums}')
print(f'True Rate:{round(t_nums/f_nums,2)}')
# Out:
# True labels:1523
# False labels:3451
# True Rate:0.44

# %%
df[df['keywords'].isna()]
# Out:
#                                                   title  year  \
# id
# 3      Graph2Seq: Scalable Learning Dynamics for Graphs  2018
# 19    SQLNet: Generating Structured Queries From Nat...  2018
# 23    Generative Models for Alignment and Data Effic...  2018
# 24    Estimation of cross-lingual news similarities ...  2018
# 29    BinaryFlex: On-the-Fly Kernel Generation in Bi...  2018
# ...                                                 ...   ...
# 4928               BackPACK: Packing more into Backprop  2020
# 4936  Posterior sampling for multi-agent reinforceme...  2020
# 4940  Cyclical Stochastic Gradient MCMC for Bayesian...  2020
# 4943      Optimal Strategies Against Generative Attacks  2020
# 4949  A Theory of Usable Information under Computati...  2020
#
#                                                abstract keywords  y
# id
# 3     Neural networks are increasingly used as a gen...      NaN  0
# 19    Synthesizing SQL queries from natural language...      NaN  0
# 23    We examine how learning from unaligned data ca...      NaN  0
# 24    Every second, innumerable text data, including...      NaN  0
# 29    In this work we present BinaryFlex, a neural n...      NaN  0
# ...                                                 ...      ... ..
# 4928  Automatic differentiation frameworks are optim...      NaN  1
# 4936  Posterior sampling for reinforcement learning ...      NaN  1
# 4940  The posteriors over neural network weights are...      NaN  1
# 4943  Generative neural models have improved dramati...      NaN  1
# 4949  We propose a new framework for reasoning about...      NaN  1
#
# [480 rows x 5 columns]

# %%
df['keywords'].unique()
# Out:
# array(['generative, hierarchical, unsupervised, semisupervised, latent, ALI, GAN',
#        'NLU, word embeddings, representation learning', nan, ...,
#        'adversarial examples, adversarial training, provable defense, convex relaxations, deep learning',
#        'Question Answering, Multi-Hop QA, Deep Learning, Knowledge Bases, Information Extraction, Data Structures for QA',
#        'federated learning'], dtype=object)

# %% [markdown]
# ## 前処理

# %%
# 大文字を小文字にする
df   = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df_t = df_t.applymap(lambda x: x.lower() if isinstance(x, str) else x)

#単語文字以外を削除
df.replace(to_replace=r'[^\w\s]', value='', regex=True, inplace=True)
df_t.replace(to_replace=r'[^\w\s]', value='', regex=True, inplace=True)

# %%
nltk.download('stopwords')

from nltk.corpus import stopwords
import string

# ストップワードの取得
stop_words = stopwords.words('english')
stop_words.extend(list(string.punctuation))

df['abstract']   = df['abstract'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words]))
df_t['abstract'] = df_t['abstract'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words]))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import re

# 数字を除去する関数
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

# "abstract"カラムの値から数字を除去
df["abstract"]   = df["abstract"].apply(remove_numbers)
df_t["abstract"] = df_t["abstract"].apply(remove_numbers)

# %%
df['abstract']
# Out:
# id
# 1       propose novel hierarchical generative model si...
# 2       words natural language follow zipfian distribu...
# 3       neural networks increasingly used general purp...
# 4       paper present technique generating artificial ...
# 5       propose unsupervised method building dynamic r...
#                               ...
# 4970    introduce convolutional conditional neural pro...
# 4971    paper study implicit regularization gradient d...
# 4972    present colt new method train neural networks ...
# 4973    consider task answering complex multihop quest...
# 4974    federated learning allows edge devices collabo...
# Name: abstract, Length: 4974, dtype: object

# %%
# NLTKライブラリのダウンロード
nltk.download('punkt')

# DataFrameから文章を取得
abst_sent_tr = df['abstract'].tolist()
abst_sent_ts = df_t['abstract'].tolist()

# 文章の単語数をカウント
sentence_len = []
for sentence in abst_sent_tr:
    tokens = nltk.word_tokenize(sentence)
    sentence_len.append(len(tokens))

print("Total word count:", sentence_len)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Total word count: [96, 73, 88, 58, 116, 87, 111, 93, 129, 80, 91, 160, 108, 125, 34, 157, 162, 53, 113, 73, 110, 90, 104, 78, 70, 97, 137, 153, 62, 88, 167, 120, 121, 125, 80, 108, 144, 92, 94, 101, 104, 95, 78, 94, 95, 84, 60, 91, 120, 73, 99, 120, 79, 119, 62, 89, 108, 123, 94, 92, 87, 47, 101, 77, 98, 79, 124, 80, 148, 119, 116, 124, 128, 108, 127, 112, 133, 103, 85, 70, 93, 78, 85, 116, 118, 100, 96, 79, 96, 84, 111, 109, 68, 129, 89, 58, 100, 50, 89, 40, 137, 86, 57, 111, 94, 62, 82, 113, 97, 106, 83, 122, 100, 98, 71, 99, 129, 105, 154, 88, 74, 102, 138, 91, 89, 96, 76, 93, 104, 50, 73, 98, 109, 113, 139, 100, 84, 89, 97, 66, 111, 84, 146, 65, 179, 43, 91, 130, 126, 91, 87, 124, 166, 93, 124, 133, 130, 97, 123, 94, 90, 89, 81, 115, 96, 80, 54, 84, 79, 70, 39, 68, 111, 123, 117, 96, 88, 80, 117, 114, 105, 47, 92, 153, 96, 98, 96, 96, 129, 65, 95, 70, 75, 75, 84, 69, 69, 122, 106, 116, 82, 102, 94, 64, 78, 79, 80, 70, 105, 64, 54, 120, 95, 83, 80, 85, 104, 97, 86, 91, 81, 84, 104, 89, 106, 109, 85, 117, 117, 137, 126, 77, 130, 54, 76, 71, 88, 85, 76, 69, 63, 177, 132, 105, 94, 106, 62, 62, 129, 91, 76, 84, 103, 75, 61, 104, 89, 86, 126, 76, 80, 63, 103, 75, 105, 125, 82, 103, 89, 73, 92, 99, 99, 86, 87, 73, 86, 111, 72, 104, 96, 147, 77, 72, 111, 119, 94, 132, 55, 82, 113, 99, 85, 99, 83, 89, 147, 64, 120, 130, 118, 101, 75, 76, 66, 86, 121, 111, 173, 89, 133, 62, 166, 127, 112, 109, 76, 108, 122, 92, 81, 64, 120, 88, 69, 82, 59, 99, 52, 120, 51, 72, 73, 66, 70, 104, 98, 67, 63, 119, 170, 63, 92, 54, 112, 95, 76, 88, 122, 123, 75, 143, 59, 68, 116, 55, 117, 87, 220, 125, 71, 62, 66, 105, 92, 132, 81, 68, 75, 149, 153, 83, 79, 213, 68, 98, 89, 103, 61, 83, 83, 87, 93, 96, 88, 122, 75, 114, 115, 95, 121, 114, 84, 67, 126, 57, 136, 109, 61, 159, 123, 183, 54, 90, 89, 68, 72, 107, 125, 139, 127, 149, 96, 99, 56, 104, 84, 65, 79, 116, 83, 131, 115, 73, 58, 87, 33, 93, 108, 136, 141, 63, 81, 114, 117, 88, 65, 112, 70, 32, 106, 149, 116, 92, 126, 82, 71, 119, 83, 105, 118, 82, 93, 80, 106, 76, 154, 75, 79, 86, 104, 88, 95, 119, 126, 114, 82, 113, 111, 103, 71, 141, 79, 129, 71, 118, 67, 146, 53, 70, 126, 94, 54, 97, 176, 72, 69, 88, 106, 118, 37, 81, 84, 88, 108, 122, 105, 75, 126, 84, 116, 111, 124, 100, 114, 89, 97, 82, 70, 73, 99, 127, 72, 89, 60, 78, 111, 103, 123, 115, 101, 48, 93, 140, 104, 120, 98, 128, 181, 119, 102, 73, 115, 110, 136, 82, 160, 80, 97, 87, 78, 88, 107, 109, 107, 145, 116, 131, 175, 129, 78, 68, 86, 74, 105, 69, 87, 129, 105, 70, 117, 113, 101, 137, 83, 70, 66, 92, 102, 111, 125, 100, 103, 91, 106, 175, 63, 155, 103, 166, 118, 162, 136, 93, 84, 89, 73, 81, 114, 104, 97, 78, 71, 93, 107, 67, 77, 109, 97, 81, 97, 86, 80, 65, 97, 113, 132, 97, 100, 102, 69, 58, 91, 79, 84, 65, 97, 171, 107, 86, 91, 119, 114, 73, 102, 87, 121, 63, 85, 145, 91, 88, 73, 82, 67, 103, 128, 115, 92, 122, 87, 96, 100, 94, 124, 89, 83, 115, 96, 60, 98, 74, 133, 149, 119, 170, 120, 120, 126, 135, 92, 106, 128, 84, 128, 153, 129, 80, 95, 90, 99, 109, 120, 91, 20, 115, 68, 149, 103, 114, 111, 106, 101, 92, 103, 74, 113, 91, 86, 109, 79, 105, 95, 90, 62, 121, 114, 126, 109, 121, 95, 101, 101, 108, 86, 101, 92, 137, 92, 121, 81, 124, 140, 115, 78, 82, 123, 110, 143, 115, 50, 70, 128, 46, 64, 76, 127, 99, 123, 88, 93, 117, 65, 110, 106, 111, 93, 48, 94, 120, 69, 93, 145, 92, 108, 124, 157, 107, 91, 68, 78, 66, 126, 70, 151, 116, 77, 66, 73, 93, 85, 113, 132, 133, 65, 129, 78, 95, 81, 81, 76, 99, 85, 82, 91, 117, 125, 49, 87, 97, 152, 105, 105, 123, 107, 65, 105, 127, 107, 57, 138, 105, 137, 120, 61, 78, 149, 92, 168, 98, 74, 103, 106, 71, 104, 103, 156, 78, 88, 64, 54, 120, 126, 59, 66, 134, 109, 81, 108, 104, 87, 95, 99, 124, 80, 90, 102, 114, 63, 99, 103, 101, 102, 101, 34, 100, 127, 71, 116, 94, 113, 93, 77, 67, 88, 47, 115, 65, 72, 113, 86, 107, 70, 90, 163, 115, 155, 73, 95, 128, 120, 81, 148, 109, 137, 81, 124, 88, 122, 84, 77, 60, 82, 85, 100, 113, 60, 78, 156, 116, 84, 102, 105, 142, 85, 150, 77, 115, 95, 73, 81, 104, 52, 93, 95, 1 ...

# %%
# ヒストグラムを作成
plt.hist(sentence_len, bins=50)

# グラフのタイトルと軸ラベルを設定
plt.title('Sentence length')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')

# グラフを表示
plt.show()

# %%
mean = np.mean(sentence_len)
median = np.median(sentence_len)
std_dev = np.std(sentence_len)
print("Mean: ", mean)
print("Median: ", median)
print("Standard deviation: ", std_dev)
# Out:
# Mean:  100.45496582227584
# Median:  98.0
# Standard deviation:  27.397949745375815

# %%
#DFの中で出現頻度が多い単語を調査
from collections import Counter

word_counts = Counter()

for row in df['abstract']:
    words = row.split()
    word_counts.update(words)

# %%
#可視化
view_nums = 10
word_counts.most_common(view_nums)#上位の単語を表示する
# Out:
# [('learning', 6145),
#  ('model', 4276),
#  ('neural', 3793),
#  ('training', 3767),
#  ('data', 3716),
#  ('networks', 3689),
#  ('models', 3331),
#  ('network', 3037),
#  ('show', 2900),
#  ('propose', 2602)]

# %%
# 棒グラフで可視化
top_words = dict(word_counts.most_common(view_nums))

plt.bar(top_words.keys(), top_words.values())
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title(f'Top {view_nums} Words')
plt.show()

# %% [markdown]
# ## 特徴量作成

# %%
###
##text2Vector by TF-IDF
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
bow_tr = vectorizer.fit_transform(df['abstract'])#4974×１６９４
bow_ts = vectorizer.fit_transform(df_t['abstract'])

from sklearn.feature_extraction.text import TfidfTransformer

transformer = TfidfTransformer()
tfidf_tr = transformer.fit_transform(bow_tr)
tfidf_ts = transformer.fit_transform(bow_ts)

# print(tfidf.toarray())

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)

# %%
### BERTによる特徴抽出
import torch
import transformers

from transformers import BertTokenizer


class BertSequenceVectorizer:
    def __init__(self, model_name="bert-base-uncased", max_len=128):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model_name = model_name
        self.tokenizer = BertTokenizer.from_pretrained(self.model_name)
        self.bert_model = transformers.BertModel.from_pretrained(self.model_name)
        self.bert_model = self.bert_model.to(self.device)
        self.max_len = max_len

    def vectorize(self, sentence: str) -> np.array:
        inp = self.tokenizer.encode(sentence)
        len_inp = len(inp)

        if len_inp >= self.max_len:
            inputs = inp[:self.max_len]
            masks = [1] * self.max_len
        else:
            inputs = inp + [0] * (self.max_len - len_inp)
            masks = [1] * len_inp + [0] * (self.max_len - len_inp)

        inputs_tensor = torch.tensor([inputs], dtype=torch.long).to(self.device)
        masks_tensor = torch.tensor([masks], dtype=torch.long).to(self.device)

        bert_out = self.bert_model(inputs_tensor, masks_tensor)
        seq_out, pooled_out = bert_out['last_hidden_state'], bert_out['pooler_output']

        if torch.cuda.is_available():
            return seq_out[0][0].cpu().detach().numpy() # 0番目は [CLS] token, 768 dim の文章特徴量
        else:
            return seq_out[0][0].detach().numpy()

# %%
BSV = BertSequenceVectorizer(
    model_name="bert-base-multilingual-uncased",
    max_len=128)
abst_features = np.stack(
    df["abstract"].fillna("").map(lambda x: BSV.vectorize(x).reshape(-1)).values
)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/672M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e13852ba77b9> in <cell line: 7>()
#       5     df["abstract"].fillna("").map(lambda x: BSV.vectorize(x).reshape(-1)).values
#       6 )
# ----> 7 features
#       8
#       9 features.shape
#
# NameError: name 'features' is not defined

# %%
###読み込みは下記
import pickle
with open(input_dir+"train_features.pkl", "rb") as f:
    abst_features = pickle.load(f)

with open(input_dir+"test_features.pkl", "rb") as f:
    X_ts = pickle.load(f)

# %%
from scipy.sparse import hstack

abst_features = hstack([abst_features, tfidf_tr])

X_ts= hstack([X_ts, tfidf_ts])

# %%
##

# %% [markdown]
# ## 学習

# %% [markdown]
# # LightGBM
# ここはつかってない

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split

#inputとTargetの設定

target = df['y'].values

X_train, X_valid, y_train, y_valid = train_test_split(X, target, test_size=0.2, random_state=42)

train_data = lgb.Dataset(X_train, label=y_train)
valid_data = lgb.Dataset(X_valid, label=y_valid)

#パラメータ
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_logloss',
    'num_leaves': 63,
    'learning_rate': 0.01,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

#modelの学習
gbm = lgb.train(params,
                train_data,
                valid_sets=[train_data, valid_data],
                num_boost_round=300,
                early_stopping_rounds=50)
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.110801 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [1]	training's binary_logloss: 0.61375	valid_1's binary_logloss: 0.61542
# Training until validation scores don't improve for 50 rounds
# [2]	training's binary_logloss: 0.611344	valid_1's binary_logloss: 0.615229
# [3]	training's binary_logloss: 0.608974	valid_1's binary_logloss: 0.615078
# [4]	training's binary_logloss: 0.60672	valid_1's binary_logloss: 0.614884
# [5]	training's binary_logloss: 0.604421	valid_1's binary_logloss: 0.614766
# [6]	training's binary_logloss: 0.602084	valid_1's binary_logloss: 0.614719
# [7]	training's binary_logloss: 0.599797	valid_1's binary_logloss: 0.61439
# [8]	training's binary_logloss: 0.59737	valid_1's binary_logloss: 0.614247
# [9]	training's binary_logloss: 0.595102	valid_1's binary_logloss: 0.614094
# [10]	training's binary_logloss: 0.592757	valid_1's binary_logloss: 0.61396
# [11]	training's binary_logloss: 0.590488	valid_1's binary_logloss: 0.613807
# [12]	training's binary_logloss: 0.58829	valid_1's binary_logloss: 0.613761
# [13]	training's binary_logloss: 0.586061	valid_1's binary_logloss: 0.613602
# [14]	training's binary_logloss: 0.583886	valid_1's binary_logloss: 0.613475
# [15]	training's binary_logloss: 0.581789	valid_1's binary_logloss: 0.613595
# [16]	training's binary_logloss: 0.579562	valid_1's binary_logloss: 0.61344
# [17]	training's binary_logloss: 0.577425	valid_1's binary_logloss: 0.613115
# [18]	training's binary_logloss: 0.575342	valid_1's binary_logloss: 0.613029
# [19]	training's binary_logloss: 0.573264	valid_1's binary_logloss: 0.612961
# [20]	training's binary_logloss: 0.571239	valid_1's binary_logloss: 0.612919
# [21]	training's binary_logloss: 0.569098	valid_1's binary_logloss: 0.61291
# [22]	training's binary_logloss: 0.566924	valid_1's binary_logloss: 0.613057
# [23]	training's binary_logloss: 0.564875	valid_1's binary_logloss: 0.612951
# [24]	training's binary_logloss: 0.562828	valid_1's binary_logloss: 0.613066
# [25]	training's binary_logloss: 0.560719	valid_1's binary_logloss: 0.612923
# [26]	training's binary_logloss: 0.558721	valid_1's binary_logloss: 0.612968
# [27]	training's binary_logloss: 0.556676	valid_1's binary_logloss: 0.612711
# [28]	training's binary_logloss: 0.55464	valid_1's binary_logloss: 0.612617
# [29]	training's binary_logloss: 0.552726	valid_1's binary_logloss: 0.612559
# [30]	training's binary_logloss: 0.550656	valid_1's binary_logloss: 0.612603
# [31]	training's binary_logloss: 0.548683	valid_1's binary_logloss: 0.612708
# [32]	training's binary_logloss: 0.546729	valid_1's binary_logloss: 0.612894
# [33]	training's binary_logloss: 0.54473	valid_1's binary_logloss: 0.612869
# [34]	training's binary_logloss: 0.542802	valid_1's binary_logloss: 0.612928
# [35]	training's binary_logloss: 0.540792	valid_1's binary_logloss: 0.612956
# [36]	training's binary_logloss: 0.538888	valid_1's binary_logloss: 0.613083
# [37]	training's binary_logloss: 0.536963	valid_1's binary_logloss: 0.612902
# [38]	training's binary_logloss: 0.53501	valid_1's binary_logloss: 0.6127
# [39]	training's binary_logloss: 0.533132	valid_1's binary_logloss: 0.612601
# [40]	training's binary_logloss: 0.531299	valid_1's binary_logloss: 0.612518
# [41]	training's binary_logloss: 0.529462	valid_1's binary_logloss: 0.612221
# [42]	training's binary_logloss: 0.527667	valid_1's binary_logloss: 0.612207
# [43]	training's binary_logloss: 0.525903	valid_1's binary_logloss: 0.612299
# [44]	training's binary_logloss: 0.524071	valid_1's binary_logloss: 0.612056
# [45]	training's binary_logloss: 0.522382	valid_1's binary_logloss: 0.612051
# [46]	training's binary_logloss: 0.520556	valid_1's binary_logloss: 0.611959
# [47]	training's binary_logloss: 0.518777	valid_1's binary_logloss: 0.612009
# [48]	training's binary_logloss: 0.517005	valid_1's binary_logloss: 0.612021
# [49]	training's binary_logloss: 0.515226	valid_1's binary_logloss: 0.611992
# [50]	training's binary_logloss: 0.513458	valid_1's binary_logloss: 0.611986
# [51]	training's binary_logloss: 0.511654	valid_1's binary_logloss: 0.61224
# [52]	training's binary_logloss: 0.509845	valid_1's binary_logloss: 0.612227
# [53]	training's binary_logloss: 0.508028	valid_1's binary_logloss: 0.612199
# [54]	training's binary_logloss: 0.506352	valid_1's binary_logloss: 0.612216
# [55]	training's binary_logloss: 0.504591	valid_1's binary_logloss: 0.61255
# [56]	training's binary_logloss: 0.502748	valid_1's binary_logloss: 0.612506
# [57]	training's binary_logloss: 0.501055	valid_1's binary_logloss: 0.612476
# [58]	training's binary_logloss: 0.499331	valid_1's binary_logloss: 0.612158
# [59]	training's binary_logloss: 0.497609	valid_1's binary_logloss: 0.612165
# [60]	training's binary_logloss: 0.495899	valid_1's binary_logloss: 0.61216
# [61]	training's binary_logloss: 0.494172	valid_1's binary_logloss: 0.612017
# [62]	training's binary_logloss: 0.49248	valid_1's binary_logloss: 0.611985
# [63]	training's binary_logloss: 0.490869	valid_1's binary_logloss: 0.612365
# [64]	training's binary_logloss: 0.48929	valid_1's binary_logloss: 0.612667
# [65]	training's binary_logloss: 0.487666	valid_1's binary_logloss: 0.612986
# [66]	training's binary_logloss: 0.48604	valid_1's binary_logloss: 0.612744
# [67]	training's binary_logloss: 0.484369	valid_1's binary_logloss: 0.612758
# [68]	training's binary_logloss: 0.482715	valid_1's binary_logloss: 0.612872
# [69]	training's binary_logloss: 0.481132	valid_1's binary_logloss: 0.613076
# [70]	training's binary_logloss: 0.479655	valid_1's binary_logloss: 0.61291
# [71]	training's binary_logloss: 0.478123	valid_1's binary_logloss: 0.612844
# [72]	training's binary_logloss: 0.476566	valid_1's binary_logloss: 0.612727
# [73]	training's binary_logloss: 0.475045	valid_1's binary_logloss: 0.612789
# [74]	training's binary_logloss: 0.473508	valid_1's binary_logloss: 0.612726
# [75]	training's binary_logloss: 0.471943	valid_1's binary_logloss: 0.61278
# [76]	training's binary_logloss: 0.470356	valid_1's binary_logloss: 0.612652
# [77]	training's binary_logloss: 0.468776	valid_1's binary_logloss: 0.612723
# [78]	training's binary_logloss: 0.467111	valid_1's binary_logloss: 0.61236
# [79]	training's binary_logloss: 0.465582	valid_1's binary_logloss: 0.612296
# [80]	training's binary_logloss: 0.463952	valid_1's binary_logloss: 0.612193
# [81]	training's binary_logloss: 0.462387	valid_1's binary_logloss: 0.612098
# [82]	training's binary_logloss: 0.460831	valid_1's binary_logloss: 0.61195
# [83]	training's binary_logloss: 0.459242	valid_1's binary_logloss: 0.612064
# [84]	training's binary_logloss: 0.45771	valid_1's binary_logloss: 0.611971
# [85]	training's binary_logloss: 0.456166	valid_1's binary_logloss: 0.612012
# [86]	training's binary_logloss: 0.454578	valid_1's binary_logloss: 0.611861
# [87]	training's binary_logloss: 0.453051	valid_1's binary_logloss: 0.611854
# [88]	training's binary_logloss: 0.451501	valid_1's binary_logloss: 0.611855
# [89]	training's binary_logloss: 0.44999	valid_1's binary_logloss: 0.611976
# [90]	training's binary_logloss: 0.448432	valid_1's binary_logloss: 0.61195
# [91]	training's binary_logloss: 0.446877	valid_1's binary_logloss: 0.611746
# [92]	training's binary_logloss: 0.445361	valid_1's binary_logloss: 0.611467
# [93]	training's binary_logloss: 0.44386	valid_1's binary_logloss: 0.611493
# [94]	training's binary_logloss: 0.442442	valid_1's binary_logloss: 0.611534
# [95]	training's binary_logloss: 0.440987	valid_1's binary_logloss: 0.611486
# [96]	training's binary_logloss: 0.439469	valid_1's binary_logloss: 0.611336
# [97]	training's binary_logloss: 0.438007	valid_1's binary_logloss: 0.611165
# [98]	training's binary_logloss: 0.436586	valid_1's binary_logloss: 0.61116
# [99]	training's binary_logloss: 0.435152	valid_1's binary_logloss: 0.610927
# [100]	training's binary_logloss: 0.433729	valid_1's binary_logloss: 0.610895
# [101]	training's binary_logloss: 0.432194	valid_1's binary_logloss: 0.61087
# [102]	training's binary_logloss: 0.430749	valid_1's binary_logloss: 0.610754
# [103]	training's binary_logloss: 0.429232	valid_1's binary_logloss: 0.610852
# [104]	training's binary_logloss: 0.427883	valid_1's binary_logloss: 0.610639
# [105]	training's binary_logloss: 0.426506	valid_1's binary_logloss: 0.61048
# [106]	training's binary_logloss: 0.425071	valid_1's binary_logloss: 0.610558
# [107]	training's binary_logloss: 0.423651	valid_1's binary_logloss: 0.610499
# [108]	training's binary_logloss: 0.422258	valid_1's binary_logloss: 0.610481
# [109]	training's binary_logloss: 0.420865	valid_1's binary_logloss: 0.610454
# [110]	training's binary_logloss: 0.419553	valid_1's binary_logloss: 0.610266
# [111]	training's binary_logloss: 0.418148	valid_1's binary_logloss: 0.610613
# [112]	training's binary_logloss: 0.416856	valid_1's binary_logloss: 0.61077
# [113]	training's binary_logloss: 0.415514	valid_1's binary_logloss: 0.610785
# [114]	training's binary_logloss: 0.414194	valid_1's binary_logloss: 0.610569
# [115]	training's binary_logloss: 0.412816	valid_1's binary_logloss: 0.610622
# [116]	training's binary_logloss: 0.41141	valid_1's binary_logloss: 0.610643
# [117]	training's binary_logloss: 0.410097	valid_1's binary_logloss: 0.610732
# [118]	training's binary_logloss: 0.408763	valid_1's binary_logloss: 0.610676
# [119]	training's binary_logloss: 0.407485	valid_1's binary_logloss: 0.610924
# [120]	training's binary_logloss: 0.406131	valid_1's binary_logloss: 0.610922
# [121]	training's binary_logloss: 0.404839	valid_1's binary_logloss: 0.610854
# [122]	training's binary_logloss: 0.403549	valid_1's binary_logloss: 0.610976
# [123]	training's binary_logloss: 0.402236	valid_1's binary_logloss: 0.610955
# [124]	training's binary_logloss: 0.400929	valid_1's binary_logloss: 0.610738
# [125]	training's binary_logloss: 0.399703	valid_1's binary_logloss: 0.610879
# [126]	training's binary_logloss: 0.398435	valid_1's binary_logloss: 0.610914
# [127]	training's binary_logloss: 0.39714	valid_1's binary_logloss: 0.611064
# [128]	training's binary_logloss: 0.395891	valid_1's binary_logloss: 0.611078
# [129]	training's binary_logloss: 0.394556	valid_1's binary_logloss: 0.611112
# [130]	training's binary_logloss: 0.393238	valid_1's binary_logloss: 0.61108
# [131]	training's binary_logloss: 0.392007	valid_1's binary_logloss: 0.611038
# [132]	training's binary_logloss: 0.390806	valid_1's binary_logloss: 0.610953
# [133]	training's binary_logloss: 0.389587	valid_1's binary_logloss: 0.611099
# [134]	training's binary_logloss: 0.38838	valid_1's binary_logloss: 0.611103
# [135]	training's binary_logloss: 0.387164	valid_1's binary_logloss: 0.611105
# [136]	training's binary_logloss: 0.385952	valid_1's binary_logloss: 0.611046
# [137]	training's binary_logloss: 0.384715	valid_1's binary_logloss: 0.610937
# [138]	training's binary_logloss: 0.383462	valid_1's binary_logloss: 0.610943
# [139]	training's binary_logloss: 0.382191	valid_1's binary_logloss: 0.611111
# [140]	training's binary_logloss: 0.380988	valid_1's binary_logloss: 0.610809
# [141]	training's binary_logloss: 0.379776	valid_1's binary_logloss: 0.610824
# [142]	training's binary_logloss: 0.37854	valid_1's binary_logloss: 0.610994
# [143]	training's binary_logloss: 0.37738	valid_1's binary_logloss: 0.611074
# [144]	training's binary_logloss: 0.376209	valid_1's binary_logloss: 0.611108
# [145]	training's binary_logloss: 0.375072	valid_1's binary_logloss: 0.611436
# [146]	training's binary_logloss: 0.373882	valid_1's binary_logloss: 0.61153
# [147]	training's binary_logloss: 0.372728	valid_1's binary_logloss: 0.611501
# [148]	training's binary_logloss: 0.371587	valid_1's binary_logloss: 0.611519
# [149]	training's binary_logloss: 0.37041	valid_1's binary_logloss: 0.611583
# [150]	training's binary_logloss: 0.369279	valid_1's binary_logloss: 0.611635
# [151]	training's binary_logloss: 0.368074	valid_1's binary_logloss: 0.611713
# [152]	training's binary_logloss: 0.366936	valid_1's binary_logloss: 0.611677
# [153]	training's binary_logloss: 0.365822	valid_1's binary_logloss: 0.611648
# [154]	training's binary_logloss: 0.364746	valid_1's binary_logloss: 0.611668
# [155]	training's binary_logloss: 0.363642	valid_1's binary_logloss: 0.611767
# [156]	training's binary_logloss: 0.362494	valid_1's binary_logloss: 0.611735
# [157]	training's binary_logloss: 0.361351	valid_1's binary_logloss: 0.611595
# [158]	training's binary_logloss: 0.360245	valid_1's binary_logloss: 0.611643
# [159]	training's binary_logloss: 0.359181	valid_1's binary_logloss: 0.611711
# [160]	training's binary_logloss: 0.358071	valid_1's binary_logloss: 0.611573
# Early stopping, best iteration is:
# [110]	training's binary_logloss: 0.419553	valid_1's binary_logloss: 0.610266

# %%
# X_ts = tfidf_ts.toarray()
# len(X_ts)

X_ts = np.stack(
    df_t["abstract"].fillna("").map(lambda x: BSV.vectorize(x).reshape(-1)).values
)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (726 > 512). Running this sequence through the model will result in indexing errors

# %%
with open(input_dir+"train_features.pkl", "wb") as f:
    pickle.dump(X, f)

with open(input_dir+"test_features.pkl", "wb") as f:
    pickle.dump(X_ts, f)

# %%
### 予測
y_pred = gbm.predict(X_ts,predict_disable_shape_check=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:859: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')

# %%
y_pred_df = pd.DataFrame(y_pred, columns=['abstract','y'])

# IDを追加
y_pred_df['id'] = df_t.index.values

# IDを先頭カラムに移動
y_pred_df = y_pred_df[['id', 'y']]

# %%
plt.hist(y_pred_df['y'],bins=50);

# %%
threshold = 0.35
y_pred_df['y'] = np.where(y_pred_df['y'] >= threshold, 1, 0)
y_pred_df['y'].sum()

# %% [markdown]
# # BERT
# ここをつかいました

# %%
df_b =df[['abstract','y']]
df_b.columns = ['text','label']#ラベル名は決まっているので固定化
df_b["label"] = df_b["label"].astype("int")#ラベルをintegerにしておく

from sklearn.model_selection import train_test_split

train_df,eval_df=train_test_split(df_b,test_size=0.1,shuffle=0.3,random_state=0)
train_df, eval_df
# Out:
# <ipython-input-15-255210d1e286>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_b["label"] = df_b["label"].astype("int")#ラベルをintegerにしておく
# (                                                   text  label
#  id
#  2876  introduce trimap dimensionality reduction tech...      0
#  1560  study problem bellman residual minimization no...      0
#  4392  adversarial examples raise questions whether n...      1
#  4291  deep neural networks dnns shown overfit datase...      1
#  1832  generative neural networks map standard possib...      0
#  ...                                                 ...    ...
#  4932  typical sequence prediction problems language ...      1
#  3265  work present waveflow smallfootprint generativ...      0
#  1654  deep neural networks achieved outstanding perf...      0
#  2608  paper study adversarial attack defence problem...      0
#  2733  consensus yet question whether adaptive gradie...      0
#
#  [4476 rows x 2 columns],
#                                                     text  label
#  id
#  2138  recurrent neural networks rnns sequentially pr...      1
#  1794  introduce geomstats python package riemannian ...      0
#  1433  multiview learning provide selfsupervision dif...      0
#  3472  imitation learning humanexpert demonstrations ...      0
#  557   leverage recent insights secondorder optimisat...      1
#  ...                                                 ...    ...
#  1162  suboydcandes  made connection nesterovs method...      0
#  534   neural programs highly accurate structured pol...      1
#  2382  memoryaugmented neural networks consisting neu...      1
#  963   understanding improving generative adversarial...      0
#  1711  construction adversarial images search problem...      0
#
#  [498 rows x 2 columns])

# %%
# !pip install simpletransformers
from simpletransformers.classification import ClassificationModel
from sklearn.metrics import accuracy_score

# %%
#学習用パラメータ
params = {
    "max_seq_length": 128,#シークエンスの最大長。この値が大きいと文章の表現力が高くなってより高い精度が期待できる。大きすぎるとoverfittingや学習時間の増大などが生じる可能性がある。
    "train_batch_size": 64,#訓練時のバッチサイズ
    "eval_batch_size": 32,
    "num_train_epochs": 10,
    "use_early_stopping": True,
    "learning_rate": 1e-5,
    "n_gpu": 4,
    "overwrite_output_dir":True
}
weight = 1/ pd.DataFrame((train_df.label).tolist()).reset_index().groupby(0).count().values#不均衡データに対処するためのパラメーター
weight_sum = weight.sum()
weight /= weight_sum

#モデルのトレーニング
model = ClassificationModel('roberta', 'roberta-base', args=params, num_labels=2, use_cuda=True)
model.train_model(train_df)

result, model_outputs, wrong_predictions = model.eval_model(eval_df)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/simpletransformers/classification/classification_model.py:612: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#   0%|          | 0/4476 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Running Epoch 0 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# Running Epoch 1 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# Running Epoch 2 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# Running Epoch 3 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# Running Epoch 4 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# Running Epoch 5 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# Running Epoch 6 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# Running Epoch 7 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# Running Epoch 8 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# Running Epoch 9 of 10:   0%|          | 0/70 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/simpletransformers/classification/classification_model.py:1454: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#   0%|          | 0/498 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/498 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
# 0.7028112449799196

# %%
#Prediction
y_pred, raw_outputs = model.predict(df_t["abstract"].tolist())
# Out:
#   0%|          | 0/6393 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
y_pred_df = pd.DataFrame(y_pred, columns=['y'])

# IDを追加
y_pred_df['id'] = df_t.index.values

# IDを先頭カラムに移動
y_pred_df = y_pred_df[['id', 'y']]

# %%
y_pred_df
# Out:
#         id  y
# 0        1  1
# 1        2  0
# 2        3  0
# 3        4  0
# 4        5  0
# ...    ... ..
# 6388  6389  0
# 6389  6390  0
# 6390  6391  0
# 6391  6392  0
# 6392  6393  0
#
# [6393 rows x 2 columns]

# %%
plt.hist(y_pred_df['y'],bins=50);

# %% [markdown]
# ## 保存

# %%
import datetime
now = datetime.datetime.now()
now_str = now.strftime('%Y%m%d_%H%M%S')  # 日時を文字列に変換

y_pred_df.to_csv(input_dir+f'result_{now_str}.csv', index=False)  # ファイル名に日時を付与して出力
